# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# Just making directory calling easier and more pretty

# %%
os.chdir('C:/Users/wissam_T/Desktop/slef improvement courses/ just random ai taining shit/online ai training course')

# %% [markdown]
# adding the dataset

# %%
book_df = pd.read_csv('datasets/amazon books datasets/Amazon_books_dataset.csv')

# %%
book_df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0              The Complete Novel of Sherlock Holmes
# 1           1  Black Holes (L) : The Reith Lectures [Paperbac...
# 2           2                                    The Kite Runner
# 3           3  Greenlights: Raucous stories and outlaw wisdom...
# 4           4  The Science of Storytelling: Why Stories Make ...
#
#                 Author                Main Genre           Sub Genre  \
# 0   Arthur Conan Doyle  Arts, Film & Photography  Cinema & Broadcast
# 1      Stephen Hawking  Arts, Film & Photography  Cinema & Broadcast
# 2      Khaled Hosseini  Arts, Film & Photography  Cinema & Broadcast
# 3  Matthew McConaughey  Arts, Film & Photography  Cinema & Broadcast
# 4           Will Storr  Arts, Film & Photography  Cinema & Broadcast
#
#              Type    Price  Rating  No. of People rated  \
# 0       Paperback  ₹169.00     4.4              19923.0
# ...

# %%
book_df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Author', 'Main Genre', 'Sub Genre', 'Type',
#        'Price', 'Rating', 'No. of People rated', 'URLs'],
#       dtype='object')

# %%
book_df.describe(include = 'all')
# Out:
#         Unnamed: 0                                              Title  \
# count    7928.0000                                               7928
# unique         NaN                                               5740
# top            NaN  AI Sports Beautiful Women Photo Collection for...
# freq           NaN                                                 13
# mean     3963.5000                                                NaN
# std      2288.7608                                                NaN
# min         0.0000                                                NaN
# 25%      1981.7500                                                NaN
# 50%      3963.5000                                                NaN
# 75%      5945.2500                                                NaN
# max      7927.0000                                                NaN
#
#                     Author        Main Genre Sub Genre       Type    Price  \
# ...

# %%
book_df.isna().sum()
# Out:
# Unnamed: 0              0
# Title                   0
# Author                 21
# Main Genre              0
# Sub Genre               0
# Type                    0
# Price                   0
# Rating                  0
# No. of People rated     0
# URLs                    0
# dtype: int64

# %%
null_data = book_df[book_df.isnull().any(axis=1)]
null_data
# Out:
#       Unnamed: 0                                              Title Author  \
# 461          461           Peppa Pig : Peppa's Super Noisy Sound Bo    NaN
# 466          466           Ladybird Big Noisy Book : Farm Hullaball    NaN
# 480          480             Peppa Pig Super Stickers Activity Book    NaN
# 486          486   Peppa Pig: Little Library [Board book] Peppa Pig    NaN
# 597          597  GERONIMO STILTON: THEA STILTON AND THE MYSTERY...    NaN
# 713          713  GERONIMO STILTON: THEA STILTON AND THE MYSTERY...    NaN
# 1015        1015       Baby Touch: Tummy Time [Board book] Ladybird    NaN
# 1028        1028           Peppa Pig : Peppa's Super Noisy Sound Bo    NaN
# 1036        1036           Ladybird Big Noisy Book : Farm Hullaball    NaN
# 1104        1104       Baby Touch: Tummy Time [Board book] Ladybird    NaN
# 1180        1180  Geronimo Stilton Cavemice #3: Help, Im in Hot ...    NaN
# ...

# %%
print(null_data.shape)
# Out:
# (21, 10)
